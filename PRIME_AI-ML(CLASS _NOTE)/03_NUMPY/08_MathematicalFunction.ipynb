# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])

# %% [markdown]
# * Aggrigation Function

# %%
np.sum(arr)
# Out:
# np.int64(15)

# %%
np.prod(arr)
# Out:
# np.int64(120)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
np.max(arr)
# Out:
# np.int64(5)

# %%
np.mean(arr)
# Out:
# np.float64(3.0)

# %%
np.median(arr)
# Out:
# np.float64(3.0)

# %%
np.std(arr)
# Out:
# np.float64(1.4142135623730951)

# %%
np.var(arr)
# Out:
# np.float64(2.0)

# %%
np.argmax(arr) # it print the index of a highest vale in an array
# Out:
# np.int64(4)

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %% [markdown]
# * power function

# %%
np.sqrt(arr)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        , 2.23606798])

# %%
np.square(arr)
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
np.pow(arr, 3)
# Out:
# array([  1,   8,  27,  64, 125])

# %% [markdown]
# * Log & Exponential

# %%
np.log(arr)
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436, 1.60943791])

# %%
np.log10(arr)
# Out:
# array([0.        , 0.30103   , 0.47712125, 0.60205999, 0.69897   ])

# %%
arr = np.log2(arr)
arr
# Out:
# array([0.        , 1.        , 1.5849625 , 2.        , 2.32192809])

# %%
np.exp(arr)
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692,  54.59815003,
#        148.4131591 ])

# %% [markdown]
# * Rounding

# %%
arr
# Out:
# array([0.        , 1.        , 1.5849625 , 2.        , 2.32192809])

# %%
np.round(arr) # find the nearest one
# Out:
# array([0., 1., 2., 2., 2.])

# %%
np.floor(arr) # round down the value --- 3.12 -> 4
# Out:
# array([0., 1., 1., 2., 2.])

# %%
np.ceil(arr) # round up the value -- 2.12 -> 2
# Out:
# array([0., 1., 2., 2., 3.])

# %%
np.trunc(arr) # remove the remaining value after decimal
# Out:
# array([0., 1., 1., 2., 2.])
